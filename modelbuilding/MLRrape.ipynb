# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("rape_data.csv")

# %% [markdown]
# # data cleaning

# %%
#remove district column
df=df.drop(['District Name'],axis=1)

# %%
#dropping bengaluru urban
df=df.drop([17])

# %%
df
# Out:
#     No. of Rape Cases  Count Of Rural Population  Count of Urban Population  \
# 0                  23                      74.66                      38.67
# 1                   2                      68.36                      25.34
# 2                   8                      76.95                      23.05
# 3                  14                      74.99                      25.01
# 4                   9                      74.58                      25.42
# 5                  14                      83.19                      16.81
# 6                   8                      64.37                      35.63
# 7                   8                      43.18                      56.82
# 8                   9                      70.85                      29.15
# 9                  13                      77.75                      22.25
# 10                 25                      62.48                      37.52
# ...

# %%
[ [min, max] for min, max in zip(df.min(), df.max()) ]
# Out:
# [[2.0, 32.0],
#  [43.18, 85.39],
#  [14.61, 56.82],
#  [51.83, 88.57],
#  [946.0, 1094.0],
#  [6.41, 30.32],
#  [1.24, 19.03],
#  [7.24, 22.4],
#  [77.6, 92.76],
#  [135.0, 476.0],
#  [0.222562248, 1.903497123],
#  [1.15114539, 5.770767097]]

# %%
import matplotlib.pyplot as plt

# %%
l=list(df.columns)
for i in range(1,len(l)):
    print(l[i])
    plt.scatter(df[l[0]],df[l[i]])
    plt.show()
# Out:
# Count Of Rural Population
# Count of Urban Population
# Literacy rate
# Sex Ratio
# SC Percentage
# ST Percentage
# Marginal Workers in each district
# Number of main workers in each district
# Density of Population(per sq km)
# Police Station Density Area Wise (per 100 sq km)
# Police Station Density Population Wise (per 1lakh population)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
df[l]=scaler.fit_transform(df[l])

# %%
df
# Out:
#     No. of Rape Cases  Count Of Rural Population  Count of Urban Population  \
# 0            0.700000                   0.745795                   0.570007
# 1            0.000000                   0.596541                   0.254205
# 2            0.200000                   0.800047                   0.199953
# 3            0.400000                   0.753613                   0.246387
# 4            0.233333                   0.743900                   0.256100
# 5            0.400000                   0.947880                   0.052120
# 6            0.200000                   0.502014                   0.497986
# 7            0.200000                   0.000000                   1.000000
# 8            0.233333                   0.655532                   0.344468
# 9            0.366667                   0.819000                   0.181000
# 10           0.766667                   0.457238                   0.542762
# ...

# %% [markdown]
# # Model Building

# %%
y=df.pop('No. of Rape Cases')
x=df

# %%
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size = 0.1, random_state = 0)

# %% [markdown]
# #### iteration1

# %%
import statsmodels.api as sm

# Note the difference in argument order
model = sm.OLS(yTrain, xTrain).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:      No. of Rape Cases   R-squared (uncentered):                   0.882
# Model:                            OLS   Adj. R-squared (uncentered):              0.795
# Method:                 Least Squares   F-statistic:                              10.16
# Date:                Sun, 30 May 2021   Prob (F-statistic):                    4.45e-05
# Time:                        15:40:01   Log-Likelihood:                          13.483
# No. Observations:                  26   AIC:                                     -4.967
# Df Residuals:                      15   BIC:                                      8.872
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#dropping Police Station Density Area Wise (per 100 sq km)\r
xTrain.pop("Police Station Density Area Wise (per 100 sq km)\r")
# Out:
# 13    0.078133
# 11    0.064959
# 26    0.392206
# 28    1.000000
# 27    0.196347
# 5     0.000000
# 14    0.465570
# 8     0.272255
# 16    0.148292
# 23    0.112510
# 18    0.335272
# 1     0.111893
# 10    0.212572
# 29    0.302568
# 6     0.123140
# 4     0.146445
# 19    0.286668
# 20    0.376398
# 9     0.188301
# 7     0.356370
# 25    0.081957
# 3     0.238867
# 0     0.115936
# 22    0.258183
# 15    0.313714
# 12    0.239162
# Name: Police Station Density Area Wise (per 100 sq km)\r, dtype: float64

# %% [markdown]
# #### iteration2

# %%
l
# Out:
# ['No. of Rape Cases',
#  'Count Of Rural Population',
#  'Count of Urban Population',
#  'Literacy rate ',
#  'Sex Ratio',
#  'SC Percentage ',
#  'ST Percentage ',
#  'Marginal Workers in each district ',
#  'Number of main workers in each district  ',
#  'Density of Population(per sq km)',
#  'Police Station Density Area Wise (per 100 sq km)\r',
#  'Police Station Density Population Wise (per 1lakh population)\n']

# %%
model = sm.OLS(yTrain, xTrain).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:      No. of Rape Cases   R-squared (uncentered):                   0.881
# Model:                            OLS   Adj. R-squared (uncentered):              0.807
# Method:                 Least Squares   F-statistic:                              11.84
# Date:                Sun, 30 May 2021   Prob (F-statistic):                    1.28e-05
# Time:                        15:40:01   Log-Likelihood:                          13.410
# No. Observations:                  26   AIC:                                     -6.820
# Df Residuals:                      16   BIC:                                      5.761
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
xTrain.pop("Police Station Density Population Wise (per 1lakh population)\n")
# Out:
# 13    0.161008
# 11    0.154817
# 26    0.154826
# 28    0.805161
# 27    0.467862
# 5     0.182911
# 14    0.157491
# 8     0.181989
# 16    0.335724
# 23    0.109946
# 18    1.000000
# 1     0.137784
# 10    0.116060
# 29    0.101064
# 6     0.039129
# 4     0.183292
# 19    0.243939
# 20    0.000000
# 9     0.778026
# 7     0.196138
# 25    0.121319
# 3     0.004435
# 0     0.060094
# 22    0.075394
# 15    0.164126
# 12    0.162499
# Name: Police Station Density Population Wise (per 1lakh population)\n, dtype: float64

# %% [markdown]
# #### iteration3

# %%
model = sm.OLS(yTrain, xTrain).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:      No. of Rape Cases   R-squared (uncentered):                   0.880
# Model:                            OLS   Adj. R-squared (uncentered):              0.816
# Method:                 Least Squares   F-statistic:                              13.81
# Date:                Sun, 30 May 2021   Prob (F-statistic):                    3.53e-06
# Time:                        15:40:01   Log-Likelihood:                          13.272
# No. Observations:                  26   AIC:                                     -8.543
# Df Residuals:                      17   BIC:                                      2.780
# Df Model:                           9
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
xTrain.pop("Sex Ratio")
# Out:
# 13    0.351351
# 11    0.189189
# 26    0.222973
# 28    0.000000
# 27    0.175676
# 5     0.270270
# 14    1.000000
# 8     0.222973
# 16    0.256757
# 23    0.317568
# 18    0.331081
# 1     0.290541
# 10    0.250000
# 29    0.202703
# 6     0.243243
# 4     0.364865
# 19    0.432432
# 20    0.500000
# 9     0.027027
# 7     0.168919
# 25    0.290541
# 3     0.067568
# 0     0.182432
# 22    0.263514
# 15    0.418919
# 12    0.175676
# Name: Sex Ratio, dtype: float64

# %% [markdown]
# #### iteration4

# %%
model = sm.OLS(yTrain, xTrain).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:      No. of Rape Cases   R-squared (uncentered):                   0.879
# Model:                            OLS   Adj. R-squared (uncentered):              0.826
# Method:                 Least Squares   F-statistic:                              16.41
# Date:                Sun, 30 May 2021   Prob (F-statistic):                    8.39e-07
# Time:                        15:40:02   Log-Likelihood:                          13.244
# No. Observations:                  26   AIC:                                     -10.49
# Df Residuals:                      18   BIC:                                    -0.4233
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
xTrain.pop("SC Percentage ")
# Out:
# 13    0.467169
# 11    0.712673
# 26    1.000000
# 28    0.634044
# 27    0.773317
# 5     0.510247
# 14    0.000000
# 8     0.070682
# 16    0.523212
# 23    0.795065
# 18    0.346299
# 1     0.438310
# 10    0.614387
# 29    0.519448
# 6     0.416144
# 4     0.601422
# 19    0.544124
# 20    0.028440
# 9     0.307821
# 7     0.134672
# 25    0.705563
# 3     0.724801
# 0     0.237139
# 22    0.479716
# 15    0.664157
# 12    0.575910
# Name: SC Percentage , dtype: float64

# %% [markdown]
# #### iteration5

# %%
model = sm.OLS(yTrain, xTrain).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:      No. of Rape Cases   R-squared (uncentered):                   0.871
# Model:                            OLS   Adj. R-squared (uncentered):              0.824
# Method:                 Least Squares   F-statistic:                              18.37
# Date:                Sun, 30 May 2021   Prob (F-statistic):                    3.25e-07
# Time:                        15:40:02   Log-Likelihood:                          12.392
# No. Observations:                  26   AIC:                                     -10.78
# Df Residuals:                      19   BIC:                                     -1.978
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
xTrain.pop('Literacy rate ' )
# Out:
# 13    0.778987
# 11    0.595536
# 26    0.614045
# 28    0.710397
# 27    0.488024
# 5     0.442569
# 14    0.936581
# 8     0.877246
# 16    0.634458
# 23    0.261296
# 18    0.505444
# 1     0.462439
# 10    0.424605
# 29    0.473326
# 6     0.633914
# 4     0.210397
# 19    0.659771
# 20    1.000000
# 9     0.695972
# 7     0.766739
# 25    0.000000
# 3     0.508438
# 0     0.589276
# 22    0.570495
# 15    0.746326
# 12    0.650789
# Name: Literacy rate , dtype: float64

# %% [markdown]
# #### iteration6

# %%
model = sm.OLS(yTrain, xTrain).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:      No. of Rape Cases   R-squared (uncentered):                   0.855
# Model:                            OLS   Adj. R-squared (uncentered):              0.811
# Method:                 Least Squares   F-statistic:                              19.59
# Date:                Sun, 30 May 2021   Prob (F-statistic):                    2.10e-07
# Time:                        15:40:02   Log-Likelihood:                          10.807
# No. Observations:                  26   AIC:                                     -9.614
# Df Residuals:                      20   BIC:                                     -2.066
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
xTrain.pop('Density of Population(per sq km)')
# Out:
# 13    0.211144
# 11    0.181818
# 26    0.736070
# 28    0.868035
# 27    0.472141
# 5     0.337243
# 14    0.568915
# 8     0.014663
# 16    0.346041
# 23    0.134897
# 18    0.671554
# 1     0.448680
# 10    0.454545
# 29    0.507331
# 6     0.275660
# 4     0.272727
# 19    0.369501
# 20    0.865103
# 9     0.574780
# 7     0.876833
# 25    0.258065
# 3     0.521994
# 0     0.648094
# 22    1.000000
# 15    0.067449
# 12    0.565982
# Name: Density of Population(per sq km), dtype: float64

# %% [markdown]
# #### iteration7

# %%
model = sm.OLS(yTrain, xTrain).fit()

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:      No. of Rape Cases   R-squared (uncentered):                   0.838
# Model:                            OLS   Adj. R-squared (uncentered):              0.799
# Method:                 Least Squares   F-statistic:                              21.73
# Date:                Sun, 30 May 2021   Prob (F-statistic):                    1.19e-07
# Time:                        15:40:02   Log-Likelihood:                          9.4028
# No. Observations:                  26   AIC:                                     -8.806
# Df Residuals:                      21   BIC:                                     -2.515
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %% [markdown]
# # Testing

# %%
xTest=xTest.drop([
 'Literacy rate ',
 'Sex Ratio',
 'SC Percentage ',
 'Density of Population(per sq km)',
 'Police Station Density Area Wise (per 100 sq km)\r',
 'Police Station Density Population Wise (per 1lakh population)\n'],axis=1)

# %%
xTest
# Out:
#     Count Of Rural Population  Count of Urban Population  ST Percentage   \
# 2                    0.800047                   0.199953        0.032040
# 21                   1.000000                   0.000000        0.518831
# 24                   0.574745                   0.425255        0.073075
#
#     Marginal Workers in each district   \
# 2                             0.714380
# 21                            0.000000
# 24                            0.996042
#
#     Number of main workers in each district
# 2                                    0.285620
# 21                                   1.000000
# 24                                   0.003958

# %%
d={
  "Count Of Rural Population": 0.80,
  "Count of Urban Population":0.19,
  "ST Percentage":0.03,
  "Marginal Workers in each district":0.71,
  "Number of main workers in each district":0.28 
}

# %%
model.predict(pd.DataFrame(d.values()).T)
# Out:
# 0    0.220985
# dtype: float64

# %%
pd.DataFrame(d.values())
# Out:
#       0
# 0  0.80
# 1  0.19
# 2  0.03
# 3  0.71
# 4  0.28

# %%
yTest
# Out:
# 2     0.200000
# 21    0.466667
# 24    0.300000
# Name: No. of Rape Cases, dtype: float64

# %%
import pickle

# %%
pickle.dump(model, open('prediction.pickle', 'wb'))

# %%
modelfile = 'prediction.pickle' 
model = pickle.load(open(modelfile, 'rb'))

# %%
model.predict(pd.DataFrame(d.values()).T)
# Out:
# 0    0.220985
# dtype: float64
