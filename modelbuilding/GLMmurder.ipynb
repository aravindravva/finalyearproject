# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("murder_data.csv")
df=df.drop(['District Name'],axis=1)
df=df.drop([17])

# %%
df
# Out:
#     Number of murders(2019)  Count of Rural Population  \
# 0                        86                      74.66
# 1                        37                      68.36
# 2                        59                      76.95
# 3                        50                      74.99
# 4                        20                      74.58
# 5                        17                      83.19
# 6                        12                      64.37
# 7                        35                      43.18
# 8                        21                      70.85
# 9                        23                      77.75
# 10                       42                      62.48
# 11                       26                      80.14
# 12                       40                      67.67
# 13                       35                      64.41
# 14                       16                      71.63
# 15                       23                      78.95
# ...

# %%
y=df.pop('Number of murders(2019)')
x=df

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf
import statsmodels.formula.api as glm

# %%
model=sm.GLM(y,x,family=sm.families.Poisson())
model=model.fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                     Generalized Linear Model Regression Results
# ...
# Dep. Variable:     Number of murders(2019)   No. Observations:                   29
# Model:                                 GLM   Df Residuals:                       23
# Model Family:                      Poisson   Df Model:                            5
# Link Function:                         log   Scale:                          1.0000
# Method:                               IRLS   Log-Likelihood:                -144.65
# Date:                     Tue, 01 Jun 2021   Deviance:                       134.18
# Time:                             11:14:34   Pearson chi2:                     130.
# No. Iterations:                          4
# Covariance Type:                 nonrobust
# ...
#                                        coef    std err          z      P>|z|      [0.025      0.975]
# ...

# %%
df.columns
# Out:
# Index(['Count of Rural Population', 'Count of Urban Population',
#        'Literacy Rate', 'Sex Ratio', 'SC Percentage ', 'ST Percentage ',
#        'Marginal Workers in each district ',
#        'Number of main workers in each district  ',
#        'Density of Population(per sq km)',
#        'Police Station Density Area Wise (per 100 sq km)',
#        'Police Station Density Population Wise (per 1lakh population)'],
#       dtype='object')

# %%
#x.pop("Police Station Density Population Wise (per 1lakh population)")
#x.pop("Marginal Workers in each district ")
#x.pop('Number of main workers in each district  ')
#x.pop('Police Station Density Area Wise (per 100 sq km)')
#x.pop('Literacy Rate')
# Out:
# 0     73.48
# 1     68.82
# 2     67.15
# 3     70.51
# 4     59.56
# 5     68.09
# 6     75.12
# 7     80.00
# 8     84.06
# 9     77.40
# 10    67.43
# 11    73.71
# 12    75.74
# 13    80.45
# 14    86.24
# 15    79.25
# 16    75.14
# 18    70.40
# 19    76.07
# 20    88.57
# 21    82.61
# 22    72.79
# 23    61.43
# 24    64.85
# 25    51.83
# 26    74.39
# 27    69.76
# 28    77.93
# 29    69.22
# Name: Literacy Rate, dtype: float64

# %%
import pickle as p

# %%
p.dump(model,open("GLMmurderprediction.pickle","wb"))

# %%
model=p.load(open("GLMmurderprediction.pickle","rb"))

# %%
d=x.iloc[0].to_dict()

# %%
model.predict(pd.DataFrame(d.values()).T)
# Out:
# 0    87.428211
# dtype: float64
